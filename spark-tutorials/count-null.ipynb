# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import *

spark = SparkSession.builder.appName("count-null").getOrCreate()

data = [
    ("Alice", None, 30),
    ("Bob", 25, None),
    (None, 35, 40),
    ("Charlie", 40, 50)
]
columns = ["Name", "Age", "Score"]
df = spark.createDataFrame(data, columns)
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# 26/01/04 12:51:05 WARN Utils: Your hostname, Hasans-MacBook-Air.local, resolves to a loopback address: 127.0.0.1; using 192.168.1.3 instead (on interface en0)
# 26/01/04 12:51:05 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/01/04 12:51:05 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
df.show()
# Out:
# +-------+----+-----+
# |   Name| Age|Score|
# +-------+----+-----+
# |  Alice|NULL|   30|
# |    Bob|  25| NULL|
# |   NULL|  35|   40|
# |Charlie|  40|   50|
# +-------+----+-----+

# %%
null_df = df.select([ count(when(col(i).isNull(), i)).alias(i) for i in df.columns])
null_df.show()
# Out:
# +----+---+-----+
# |Name|Age|Score|
# +----+---+-----+
# |   1|  1|    1|
# +----+---+-----+
