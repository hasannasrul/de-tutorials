# %%
import polars as pl

# %%
df = pl.DataFrame({
    "foo": [1, 2, 3],
    "bar": ["a", "b", "c"],
    "baz": [0.1, 0.2, 0.3],
})

# %%
df.show()
# Out:
# <div><style>
# .dataframe > thead > tr,
# .dataframe > tbody > tr {
#   text-align: right;
#   white-space: pre-wrap;
# }
# </style>
# <small>shape: (3, 3)</small><table border="1" class="dataframe"><thead><tr><th>foo</th><th>bar</th><th>baz</th></tr><tr><td>i64</td><td>str</td><td>f64</td></tr></thead><tbody><tr><td>1</td><td>&quot;a&quot;</td><td>0.1</td></tr><tr><td>2</td><td>&quot;b&quot;</td><td>0.2</td></tr><tr><td>3</td><td>&quot;c&quot;</td><td>0.3</td></tr></tbody></table></div>
